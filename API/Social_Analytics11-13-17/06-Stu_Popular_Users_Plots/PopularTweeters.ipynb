# %%
# Dependencies
import tweepy
import json
import pandas as pd

# Your Twitter API Keys
consumer_key = "imIIAxheqCEuHq8mHk3lNJO0t"
consumer_secret = "1l8hfeVQGbChQtZ7CIKsgtPimg38cAALpIZ9QreW8vG82lCTEs"
access_token = "770107676957216769-Zp2RA9bdYHjOEa8fqCDOAhfNbAdMALG"
access_token_secret = "OsumkVbxLfbo3sX3LcJhouwDPbFmswtsFl8oadz7gOqOn"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Import CSV file into Data Frame
popular_tweeters = pd.read_csv("PopularAccounts.csv", dtype=str)
popular_tweeters
# Out:
#         Screen Name Real Name Tweets Followers Following Favorites Count
# 0         katyperry       NaN    NaN       NaN       NaN             NaN
# 1      justinbieber       NaN    NaN       NaN       NaN             NaN
# 2       BarackObama       NaN    NaN       NaN       NaN             NaN
# 3     Taylorswift13       NaN    NaN       NaN       NaN             NaN
# 4           rihanna       NaN    NaN       NaN       NaN             NaN
# 5           youtube       NaN    NaN       NaN       NaN             NaN
# 6      theellenshow       NaN    NaN       NaN       NaN             NaN
# 7          ladygaga       NaN    NaN       NaN       NaN             NaN
# 8           twitter       NaN    NaN       NaN       NaN             NaN
# 9       jtimberlake       NaN    NaN       NaN       NaN             NaN
# 10    britneyspears       NaN    NaN       NaN       NaN             NaN
# 11        cristiano       NaN    NaN       NaN       NaN             NaN
# 12    kimkardashian       NaN    NaN       NaN       NaN             NaN
# 13      selenagomez       NaN    NaN       NaN       NaN             NaN
# 14           cnnbrk       NaN    NaN       NaN       NaN             NaN
# 15      jimmyfallon       NaN    NaN       NaN       NaN             NaN
# 16     arianagrande       NaN    NaN       NaN       NaN             NaN
# 17          shakira       NaN    NaN       NaN       NaN             NaN
# 18         ddlovato       NaN    NaN       NaN       NaN             NaN
# 19              jlo       NaN    NaN       NaN       NaN             NaN
# 20        instagram       NaN    NaN       NaN       NaN             NaN
# 21            oprah       NaN    NaN       NaN       NaN             NaN
# 22            drake       NaN    NaN       NaN       NaN             NaN
# 23        kingjames       NaN    NaN       NaN       NaN             NaN
# 24          nytimes       NaN    NaN       NaN       NaN             NaN
# 25        billgates       NaN    NaN       NaN       NaN             NaN
# 26              cnn       NaN    NaN       NaN       NaN             NaN
# 27   kevinhart4real       NaN    NaN       NaN       NaN             NaN
# 28       mileycyrus       NaN    NaN       NaN       NaN             NaN
# 29     onedirection       NaN    NaN       NaN       NaN             NaN
# 30     sportscenter       NaN    NaN       NaN       NaN             NaN
# 31             espn       NaN    NaN       NaN       NaN             NaN
# 32      bbcbreaking       NaN    NaN       NaN       NaN             NaN
# 33     harry_styles       NaN    NaN       NaN       NaN             NaN
# 34             pink       NaN    NaN       NaN       NaN             NaN
# 35       liltunechi       NaN    NaN       NaN       NaN             NaN
# 36       wizkhalifa       NaN    NaN       NaN       NaN             NaN
# 37    niallofficial       NaN    NaN       NaN       NaN             NaN
# 38        brunomars       NaN    NaN       NaN       NaN             NaN
# 39            adele       NaN    NaN       NaN       NaN             NaN
# 40     narendramodi       NaN    NaN       NaN       NaN             NaN
# 41         neymarjr       NaN    NaN       NaN       NaN             NaN
# 42        kanyewest       NaN    NaN       NaN       NaN             NaN
# 43             kaka       NaN    NaN       NaN       NaN             NaN
# 44      actuallynph       NaN    NaN       NaN       NaN             NaN
# 45  realdonaldtrump       NaN    NaN       NaN       NaN             NaN
# 46       danieltosh       NaN    NaN       NaN       NaN             NaN
# 47       srbachchan       NaN    NaN       NaN       NaN             NaN
# 48       aliciakeys       NaN    NaN       NaN       NaN             NaN
# 49              nba       NaN    NaN       NaN       NaN             NaN

# %%
# See what API response looks like
test_account = api.get_user("katyperry")
test_account
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Fri Feb 20 23:45:56 +0000 2009',
#  'default_profile': False,
#  'default_profile_image': False,
#  'description': '',
#  'entities': {'description': {'urls': []},
#   'url': {'urls': [{'display_url': 'katyperry.com/tour',
#      'expanded_url': 'http://www.katyperry.com/tour',
#      'indices': [0, 23],
#      'url': 'https://t.co/UCVo8NkmAc'}]}},
#  'favourites_count': 5817,
#  'follow_request_sent': False,
#  'followers_count': 106286019,
#  'following': False,
#  'friends_count': 204,
#  'geo_enabled': True,
#  'has_extended_profile': True,
#  'id': 21447363,
#  'id_str': '21447363',
#  'is_translation_enabled': True,
#  'is_translator': False,
#  'lang': 'en',
#  'listed_count': 141921,
#  'location': '',
#  'name': 'KATY PERRY',
#  'notifications': False,
#  'profile_background_color': 'CECFBC',
#  'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000168797027/kSZ-ewZo.jpeg',
#  'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000168797027/kSZ-ewZo.jpeg',
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21447363/1504044451',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/902653914465550336/QE3287ZJ_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/902653914465550336/QE3287ZJ_normal.jpg',
#  'profile_link_color': 'D55732',
#  'profile_location': None,
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': '78C0A8',
#  'profile_text_color': '5E412F',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'katyperry',
#  'status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Nov 14 01:07:35 +0000 2017',
#   'entities': {'hashtags': [{'indices': [16, 31], 'text': 'WITNESSTHETOUR'}],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/930240763027275776',
#      'indices': [117, 140],
#      'url': 'https://t.co/YuihMz5J4l'}],
#    'user_mentions': []},
#   'favorite_count': 4294,
#   'favorited': False,
#   'geo': None,
#   'id': 930240763027275776,
#   'id_str': '930240763027275776',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1095,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Turning 3⃣3⃣ on #WITNESSTHETOUR: I got woken up w/ confetti 🎉, attacked with silly string during yoga 🙈and all my f… https://t.co/YuihMz5J4l',
#   'truncated': True},
#  'statuses_count': 8733,
#  'time_zone': 'Alaska',
#  'translator_type': 'regular',
#  'url': 'https://t.co/UCVo8NkmAc',
#  'utc_offset': -32400,
#  'verified': True}

# %%
# Iterate through DataFrame
for index, row in popular_tweeters.iterrows():
    
    # Error handling
    try:
        # Grab the username
        target_user = row["Screen Name"]

        # Use the username with the Twitter API get_user
        user_account = api.get_user(target_user)
        user_real_name = user_account["name"]

        # Get the specific column data
        user_tweets = user_account["statuses_count"]
        user_followers = user_account["followers_count"]
        user_following = user_account["friends_count"]
        user_favorites = user_account["favourites_count"]

        # Replace the row information for each
        popular_tweeters.set_value(index, "Real Name", user_real_name)
        popular_tweeters.set_value(index, "Tweets", user_tweets)
        popular_tweeters.set_value(index, "Followers", user_followers)
        popular_tweeters.set_value(index, "Following", user_following)
        popular_tweeters.set_value(index, "Favorites Count", user_favorites)
    
    # If an error is encountered, move on with the next iteration of the loop
    except:
        continue
        
popular_tweeters
# Out:
#         Screen Name            Real Name  Tweets  Followers Following  \
# 0         katyperry           KATY PERRY    8733  106286032       204
# 1      justinbieber        Justin Bieber   30647  103289845    315545
# 2       BarackObama         Barack Obama   15479   96792420    626660
# 3     Taylorswift13         Taylor Swift      60   85614707         0
# 4           rihanna              Rihanna   10033   82187918      1132
# 5           youtube              YouTube   21119   70411871      1029
# 6      theellenshow      Ellen DeGeneres   15304   75369501     35987
# 7          ladygaga            Lady Gaga    8587   73527409    128607
# 8           twitter              Twitter    6269   62112315       170
# 9       jtimberlake    Justin Timberlake    3690   63525000       254
# 10    britneyspears       Britney Spears    5322   55989575    389444
# 11        cristiano    Cristiano Ronaldo    3041   63679714        96
# 12    kimkardashian  Kim Kardashian West   24883   56985913       127
# 13      selenagomez         Selena Gomez    4331   54498006      1263
# 14           cnnbrk    CNN Breaking News   58795   53429154       120
# 15      jimmyfallon         jimmy fallon   10217   49684504      7753
# 16     arianagrande        Ariana Grande   40401   55211163     65191
# 17          shakira              Shakira    5232   49166238       209
# 18         ddlovato          Demi Lovato   16467   51568010       548
# 19              jlo       Jennifer Lopez   12306   44033140      1734
# 20        instagram            Instagram   11271   39446226         4
# 21            oprah        Oprah Winfrey   12327   39847704       288
# 22            drake               Drizzy    1712   36425143       635
# 23        kingjames         LeBron James    5553   39519633       176
# 24          nytimes   The New York Times  298946   40143385       886
# 25        billgates           Bill Gates    2510   40914878       184
# 26              cnn                  CNN  157291   38402524      1115
# 27   kevinhart4real           Kevin Hart   34751   34982394       555
# 28       mileycyrus      Miley Ray Cyrus    9001   37648038       376
# 29     onedirection        One Direction    9908   31790075      3920
# 30     sportscenter         SportsCenter   99884   35100714      1661
# 31             espn                 ESPN   92461   33758203       285
# 32      bbcbreaking    BBC Breaking News   33419   35815058         3
# 33     harry_styles        Harry Styles.    5395   31333476      2046
# 34             pink                 P!nk    6736   31111616       447
# 35       liltunechi    Lil Wayne WEEZY F    1739   32068569        48
# 36       wizkhalifa          Wiz Khalifa   43664   32502775       835
# 37    niallofficial          Niall Horan   12298   36121567      5974
# 38        brunomars           Bruno Mars    4063   37273461       109
# 39            adele                Adele     298   28825924       157
# 40     narendramodi        Narendra Modi   17237   36670763      1854
# 41         neymarjr            Neymar Jr   41082   34943498       747
# 42        kanyewest                  NaN     NaN        NaN       NaN
# 43             kaka                 Kaka    4787   28810020       354
# 44      actuallynph  Neil Patrick Harris    2778   27607971       117
# 45  realdonaldtrump      Donald J. Trump   36370   42617738        45
# 46       danieltosh          daniel tosh   13618   27517920       131
# 47       srbachchan     Amitabh Bachchan   59818   31056375         7
# 48       aliciakeys          Alicia Keys    7284   29389043       689
# 49              nba                  NBA  177486   26836524      1671
#
#    Favorites Count
# 0             5817
# 1             3449
# 2               10
# 3              102
# 4             1023
# 5             1674
# 6              576
# 7             1685
# 8             5211
# 9               48
# 10            2461
# 11               0
# 12               1
# 13             167
# 14              18
# 15              49
# 16           32625
# 17            1232
# 18            1892
# 19            6586
# 20             152
# 21             149
# 22              11
# 23              83
# 24           15798
# 25              27
# 26            1478
# 27              83
# 28             202
# 29             303
# 30            1158
# 31              95
# 32               0
# 33              76
# 34             405
# 35              13
# 36              51
# 37             362
# 38             177
# 39               0
# 40               0
# 41             808
# 42             NaN
# 43              75
# 44             176
# 45              23
# 46               2
# 47              60
# 48             219
# 49             246

# %%
# Export to CSV
popular_tweeters.to_csv("populartweeterscomplete.csv", index=False)

# %%
# Calculate Averages of the following: "Tweets"; "Followers"; "Follwing"; "Favorites Count"
# See "Create DataFrame" below for the variable names you should use
average_tweet_count = popular_tweeters["Tweets"].mean()
average_followers = popular_tweeters["Followers"].mean()
average_following_count = popular_tweeters["Following"].mean()
average_favorites_count = popular_tweeters["Favorites Count"].mean()

# Create DataFrame
averages = {"Average Tweet Count": [average_tweet_count], 
            "Average Follower Count": [average_followers], 
            "Average Following Count": [average_following_count],
            "Average Favorites Count": [average_favorites_count]}

# Create a Dataframe of the averages
average_df = pd.DataFrame(averages)
average_df
# Out:
#    Average Favorites Count  Average Follower Count  Average Following Count  \
# 0              1772.040816            4.798038e+07             32705.734694
#
#    Average Tweet Count
# 0         30695.612245
