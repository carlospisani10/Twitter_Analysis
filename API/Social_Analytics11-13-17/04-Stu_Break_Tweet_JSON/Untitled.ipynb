# %%
# Dependencies
import json

# %%
# Read JSONs
sample = "Sample.json"

# Sample 1 Data
with open(sample) as data_file:
    sample_data = json.load(data_file)

    # Cleaned up JSON
    print(json.dumps(sample_data[0], sort_keys=True, indent=4))
    print("------------------------------------------------------------------")
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Mar 09 00:03:50 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/8\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/839627753116827648",
#                 "indices": [
#                     114,
#                     137
#                 ],
#                 "url": "https://t.co/zEOpWLibDy"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 58,
#     "favorited": false,
#     "geo": null,
#     "id": 839627753116827648,
#     "id_str": "839627753116827648",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
# ...

# %%
 # Using the Sample_Data provided above, write code to answer each of the
    # following questions:

 #Question 1: With what account are the tweets in the Sample associated?
account = sample_data[0]["user"]["name"]
account  
# Question 2: How many followers does this account have associated with it?
follower = sample_data[0]["user"]["followers_count"]
follower
# Question 3: How many tweets are included in the Sample?
tweets = len(sample_data)
tweets
# Question 4: How many tweets total has this account made?
number = sample_data[0]["user"]["statuses_count"]
# Question 5: What was the text in the most recent tweet?

# Question 6: What was the text associated with each of the tweets included in this sample data?
for tweet in sample_data:
    print("-" + tweet["text"])
print("")
# Question 7 (Bonus): Which of the user's tweets was most frequently retweeted? How many retweets were there?
top_tweet_text = ""
top_retweet_count = 0

for tweet in sample_data:
    if(tweet["retweet_count"] > top_retweet_count):
        top_tweet_text = text["tweet"]
        top_retweet_count = tweet["retweet_count"]

print(f'{top_tweet_text} had the most retweets with {top_retweet_count}')
# Out:
# -Jon Huntsman, former ambassador to China under Obama, tapped as US ambassador to Russia, senior US officials say… https://t.co/zEOpWLibDy
# -Congress takes aim at a visa program that has been key to at least one Trump family business venture… https://t.co/Zl1d8XJSd5
# -Rep. Cummings says he told President Trump there’s no voter fraud, “but there is voter suppression” https://t.co/qJkdvVTLHl
# -Cummings says he told Trump he shouldn't make it sound like all African Americans are afraid to walk down the street https://t.co/K0ng9z1u1V
# -Key interest groups and industry stakeholders are lining up in opposition to the new GOP health care plan… https://t.co/BsHDmR9ffh
# -Gay veterans group says it was denied entry to Boston's St. Patrick's Day parade https://t.co/ww60VVGFmZ https://t.co/cPd4OEeyUF
# -RT @CNNSitRoom: Schiff: Doesn’t Pres. Trump owe an apology not only to the former president, but to the “entire American people” over wiret…
# ...

# %%
#with open(sample) as data_file:
    #sample_data = json.load(data_file)

    #print(json.dumps(sample_data[1], sort_keys=True, indent=4))
    #print("------------------------------------------------------------------")
