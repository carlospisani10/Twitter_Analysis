# %%
import requests
import matplotlib.pyplot as plt
import requests as req
import pandas as pd
import openweathermapy as ow
import json
from citipy import citipy
import numpy as np
import random
from weather_key2 import api_key

# %%
# Create a settings object with your API key and preferred units
settings = {"units": "metric", "appid": api_key}

# %%
# Get data for each city in cities.csv
weather_data = []
with open("Resources/cities.csv") as cities:
    cities = csv.reader(cities)
    cities = [city[0] for city in cities]
    weather_data = [ow.get_current(city, **settings) for city in cities]
weather_data
# Out:
# [{'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 48.85, 'lon': 2.35},
#   'dt': 1510878600,
#   'id': 2988507,
#   'main': {'humidity': 87,
#    'pressure': 1025,
#    'temp': 7.28,
#    'temp_max': 9,
#    'temp_min': 5},
#   'name': 'Paris',
#   'sys': {'country': 'FR',
#    'id': 5617,
#    'message': 0.1667,
#    'sunrise': 1510902170,
#    'sunset': 1510934869,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 249.002, 'speed': 1.21}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 51.51, 'lon': -0.13},
#   'dt': 1510878000,
#   'id': 2643743,
#   'main': {'humidity': 70,
#    'pressure': 1028,
#    'temp': 4.23,
#    'temp_max': 7,
#    'temp_min': 3},
#   'name': 'London',
#   'sys': {'country': 'GB',
#    'id': 5091,
#    'message': 0.1674,
#    'sunrise': 1510903332,
#    'sunset': 1510934896,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': 59.91, 'lon': 10.75},
#   'dt': 1510878000,
#   'id': 3143244,
#   'main': {'humidity': 75,
#    'pressure': 1007,
#    'temp': 4,
#    'temp_max': 4,
#    'temp_min': 4},
#   'name': 'Oslo',
#   'sys': {'country': 'NO',
#    'id': 5325,
#    'message': 0.0073,
#    'sunrise': 1510903179,
#    'sunset': 1510929816,
#    'type': 1},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 220, 'speed': 4.6}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 39.91, 'lon': 116.4},
#   'dt': 1510876800,
#   'id': 1816670,
#   'main': {'humidity': 18,
#    'pressure': 1025,
#    'temp': 5,
#    'temp_max': 5,
#    'temp_min': 5},
#   'name': 'Beijing',
#   'sys': {'country': 'CN',
#    'id': 7405,
#    'message': 0.1642,
#    'sunrise': 1510873279,
#    'sunset': 1510909015,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 310, 'speed': 11}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 55.75, 'lon': 37.62},
#   'dt': 1510876800,
#   'id': 524901,
#   'main': {'humidity': 93,
#    'pressure': 1019,
#    'temp': 1.34,
#    'temp_max': 2,
#    'temp_min': 1},
#   'name': 'Moscow',
#   'sys': {'country': 'RU',
#    'id': 7323,
#    'message': 0.1671,
#    'sunrise': 1510895340,
#    'sunset': 1510924760,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 250, 'speed': 4}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': 43.11, 'lon': 131.87},
#   'dt': 1510876800,
#   'id': 2013348,
#   'main': {'humidity': 67,
#    'pressure': 1021,
#    'temp': -8,
#    'temp_max': -8,
#    'temp_min': -8},
#   'name': 'Vladivostok',
#   'sys': {'country': 'RU',
#    'id': 7251,
#    'message': 0.1636,
#    'sunrise': 1510870041,
#    'sunset': 1510904824,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 80, 'speed': 2}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 35.95, 'lon': 137.27},
#   'dt': 1510878120,
#   'id': 1853908,
#   'main': {'humidity': 100,
#    'pressure': 1021,
#    'temp': -1,
#    'temp_max': -1,
#    'temp_min': -1},
#   'name': 'Osaka',
#   'sys': {'country': 'JP',
#    'id': 7506,
#    'message': 0.1683,
#    'sunrise': 1510867739,
#    'sunset': 1510904539,
#    'type': 1},
#   'visibility': 500,
#   'weather': [{'description': 'fog', 'icon': '50d', 'id': 741, 'main': 'Fog'}],
#   'wind': {'speed': 1}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 21.31, 'lon': -157.86},
#   'dt': 1510876620,
#   'id': 5856195,
#   'main': {'humidity': 42,
#    'pressure': 1015,
#    'temp': 26.62,
#    'temp_max': 29,
#    'temp_min': 24},
#   'name': 'Honolulu',
#   'sys': {'country': 'US',
#    'id': 819,
#    'message': 0.0036,
#    'sunrise': 1510937027,
#    'sunset': 1510976943,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03d',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 50, 'gust': 11.3, 'speed': 8.2}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -34.83, 'lon': -56.17},
#   'dt': 1510876800,
#   'id': 3441575,
#   'main': {'humidity': 71,
#    'pressure': 1013,
#    'temp': 14,
#    'temp_max': 14,
#    'temp_min': 14},
#   'name': 'Montevideo',
#   'sys': {'country': 'UY',
#    'id': 4623,
#    'message': 0.1675,
#    'sunrise': 1510907372,
#    'sunset': 1510957818,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 70, 'speed': 3.1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 36.19, 'lon': 44.01},
#   'dt': 1510876800,
#   'id': 95446,
#   'main': {'humidity': 40,
#    'pressure': 1020,
#    'temp': 11,
#    'temp_max': 11,
#    'temp_min': 11},
#   'name': 'Erbil',
#   'sys': {'country': 'IQ',
#    'id': 7161,
#    'message': 0.1688,
#    'sunrise': 1510890167,
#    'sunset': 1510926881,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 330, 'speed': 2.6}}]

# %%
# Create an "extracts" object to get the temperature, latitude,
# and longitude in each city
summary = ["main.temp", "coord.lat", "coord.lon"]

# Create a Pandas DataFrame with the results
data = [response(*summary) for response in weather_data]
print(data)

column_names = ["Temperature", "Latitude", "Longitude"]
weather_data = pd.DataFrame(data, index=cities, columns=column_names)
weather_data
# Out:
# [(7.28, 48.85, 2.35), (4.23, 51.51, -0.13), (4, 59.91, 10.75), (5, 39.91, 116.4), (1.34, 55.75, 37.62), (-8, 43.11, 131.87), (-1, 35.95, 137.27), (26.62, 21.31, -157.86), (14, -34.83, -56.17), (11, 36.19, 44.01)]
#              Temperature  Latitude  Longitude
# Paris               7.28     48.85       2.35
# London              4.23     51.51      -0.13
# Oslo                4.00     59.91      10.75
# Beijing             5.00     39.91     116.40
# Moscow              1.34     55.75      37.62
# Vladivostok        -8.00     43.11     131.87
# Osaka              -1.00     35.95     137.27
# Honolulu           26.62     21.31    -157.86
# Montevideo         14.00    -34.83     -56.17
# Erbil              11.00     36.19      44.01
